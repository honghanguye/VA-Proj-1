# %%
import pandas as pd

# %%
df_rating = pd.DataFrame(df_rating, columns = ['rating', 'num_of_reviews'])

# %%
df_rating
# Out:
#                                           rating  num_of_reviews
# 0   {'rating': 8.67527, 'num_of_reviews': 54330}             NaN
# 1   {'rating': 8.65313, 'num_of_reviews': 33285}             NaN
# 2   {'rating': 8.56688, 'num_of_reviews': 48768}             NaN
# 3   {'rating': 8.56684, 'num_of_reviews': 23194}             NaN
# 4    {'rating': 8.6449, 'num_of_reviews': 19295}             NaN
# ..                                           ...             ...
# 95  {'rating': 7.69721, 'num_of_reviews': 32490}             NaN
# 96  {'rating': 7.75361, 'num_of_reviews': 21005}             NaN
# 97  {'rating': 7.72926, 'num_of_reviews': 21781}             NaN
# 98  {'rating': 7.95809, 'num_of_reviews': 13863}             NaN
# 99  {'rating': 7.76522, 'num_of_reviews': 33857}             NaN
#
# [100 rows x 2 columns]

# %%
recommendation = pd.read_csv('recommendations-2021-12-31.csv',sep=',')
games = pd.read_csv('bgg_Gameitems.csv',sep=',')

# %%
recommendation.head()
# Out:
#        ID                               Name  Year  Rank  Average  \
# 0  174430                         Gloomhaven  2017     1     8.74
# 1  161936          Pandemic Legacy: Season 1  2015     2     8.60
# 2  224517                  Brass: Birmingham  2018     3     8.67
# 3  167791                  Terraforming Mars  2016     4     8.42
# 4  233078  Twilight Imperium: Fourth Edition  2017     5     8.68
#
#    Bayes average  Users rated  \
# 0          8.511        47555
# 1          8.444        44877
# 2          8.417        25216
# 3          8.273        73742
# 4          8.260        15911
#
#                                                  URL  \
# 0                       /boardgame/174430/gloomhaven
# 1         /boardgame/161936/pandemic-legacy-season-1
# 2                 /boardgame/224517/brass-birmingham
# 3                /boardgame/167791/terraforming-mars
# 4  /boardgame/233078/twilight-imperium-fourth-edi...
#
# ...

# %%
# create new column for family with just the string before the first period
games['sim_family'] = games['family'].str.split(':').str[0]

# %%
#new dataframe with only numerical columns
games_num = games[(games.columns.dtype == 'int64')OR (games.columns.dtype == 'float64')]
# Out:
#   File "C:\Users\riven\AppData\Local\Temp/ipykernel_14084/2591321799.py", line 2
#     games_num = games[(games.columns.dtype == 'int64')OR (games.columns.dtype == 'float64')]
#                                                       ^
# SyntaxError: invalid syntax

# %%
games_num = games.select_dtypes(include=['int64', 'float64'])

# %%
merged_df = pd.merge(recommendation,games, how='left', left_on='ID', right_on='bgg_id')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 75 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   1000 non-null   int64
#  1   Name                 1000 non-null   object
#  2   Year                 1000 non-null   int64
#  3   Rank                 1000 non-null   int64
#  4   Average              1000 non-null   float64
#  5   Bayes average        1000 non-null   float64
#  6   Users rated          1000 non-null   int64
#  7   URL                  1000 non-null   object
#  8   Thumbnail            1000 non-null   object
#  9   recommendation1      1000 non-null   int64
#  10  recommendation2      1000 non-null   int64
#  11  recommendation3      1000 non-null   int64
#  12  recommendation4      1000 non-null   int64
#  13  recommendation5      1000 non-null   int64
#  14  recommendation6      1000 non-null   int64
# ...

# %%
merged_df = merged_df.dropna(thresh=990, axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Name              1000 non-null   object
#  2   Year              1000 non-null   int64
#  3   Rank              1000 non-null   int64
#  4   Average           1000 non-null   float64
#  5   Bayes average     1000 non-null   float64
#  6   Users rated       1000 non-null   int64
#  7   URL               1000 non-null   object
#  8   Thumbnail         1000 non-null   object
#  9   recommendation1   1000 non-null   int64
#  10  recommendation2   1000 non-null   int64
#  11  recommendation3   1000 non-null   int64
#  12  recommendation4   1000 non-null   int64
#  13  recommendation5   1000 non-null   int64
#  14  recommendation6   1000 non-null   int64
#  15  bgg_id            1000 non-null   int64
# ...

# %%
merged_df = merged_df.dropna()

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                986 non-null    int64
#  1   Name              986 non-null    object
#  2   Year              986 non-null    int64
#  3   Rank              986 non-null    int64
#  4   Average           986 non-null    float64
#  5   Bayes average     986 non-null    float64
#  6   Users rated       986 non-null    int64
#  7   URL               986 non-null    object
#  8   Thumbnail         986 non-null    object
#  9   recommendation1   986 non-null    int64
#  10  recommendation2   986 non-null    int64
#  11  recommendation3   986 non-null    int64
#  12  recommendation4   986 non-null    int64
#  13  recommendation5   986 non-null    int64
#  14  recommendation6   986 non-null    int64
#  15  bgg_id            986 non-null    int64
# ...

# %%
merged_df
